# %%
import os
import pathlib
import pandas as pd

from copy import deepcopy

# %%
local_folder = "/Users/massimilianoarca/Documents/PoliMi/Research Grant/SafeCREW/Data/Tarragona"

raw_data_path = os.path.join(local_folder, "Raw Data")
clean_data_path = os.path.join(local_folder, "Clean Data")

eb_measure_path = os.path.join(raw_data_path, "EB0_EB1.xlsx")
eb0_sensor_path = os.path.join(raw_data_path, "Dades sensor online EB0")
eb1_sensor_path = os.path.join(raw_data_path, "Dades sensor online EB1")
thm_measure_path = os.path.join(raw_data_path, "THMs_ARBOÇ_2022.csv")

# %% [markdown]
# # EB0 - EB1 laboratory measurements

# %%
raw_eb0_measure_df = pd.read_excel(eb_measure_path, sheet_name="EB0")
raw_eb1_measure_df = pd.read_excel(eb_measure_path, sheet_name="EB1")

# %% [markdown]
# ## EB0

# %%
raw_eb0_measure_df
# Out:
#        any_   FOLDERNO        data            SAMPDATE   APPRSTS  CLSAMPNO  \
# 0      2018  180002852  17/07/2018 2018-07-17 03:00:00  Released  CAMPREDÓ
# 1      2018  180002852  17/07/2018 2018-07-17 03:00:00  Released  CAMPREDÓ
# 2      2018  180002852  17/07/2018 2018-07-17 03:00:00  Released  CAMPREDÓ
# 3      2018  180002852  17/07/2018 2018-07-17 03:00:00  Released  CAMPREDÓ
# 4      2018  180002852  17/07/2018 2018-07-17 03:00:00  Released  CAMPREDÓ
# ...     ...        ...         ...                 ...       ...       ...
# 34743  2023  230000304  06/02/2023 2023-02-06 04:30:00  Released  CAMPREDÓ
# 34744  2023  230000304  06/02/2023 2023-02-06 04:30:00  Released  CAMPREDÓ
# 34745  2023  230000304  06/02/2023 2023-02-06 04:30:00  Released  CAMPREDÓ
# 34746  2023  230000304  06/02/2023 2023-02-06 04:30:00  Released  CAMPREDÓ
# 34747  2023  230000304  06/02/2023 2023-02-06 04:30:00  Released  CAMPREDÓ
#
#        ENVSAMPOINTID  PROFILE DISPSTS               TESTNO  \
# 0                320  Default     NaN  Material Particulat
# 1                320  Default     NaN  Material Particulat
# 2                320  Default     NaN  Material Particulat
# 3                320  Default     NaN  Material Particulat
# 4                320  Default     NaN  Material Particulat
# ...              ...      ...     ...                  ...
# 34743            320  Default     NaN        Oxohalogenats
# 34744            320  Default     NaN        Oxohalogenats
# 34745            320  Default     NaN        Oxohalogenats
# 34746            320  Default     NaN        Oxohalogenats
# 34747            320  Default     NaN        Oxohalogenats
#
#                                        ANALYTE  RESULTASNUMERIC    units  \
# 0      Comptatge Total de partícules comptades        103700.00  part/mL
# 1                       Mida de massa més gran            52.00       um
# 2                            Mida més abundant             1.00       um
# 3               Mida mitjana de les partícules             4.00       um
# 4         Quantitat més abundant de partícules         23249.00  part/mL
# ...                                        ...              ...      ...
# 34743                                  Bromats             0.00     µg/L
# 34744                                   Bromur           138.00     µg/L
# 34745                                   Clorat             0.04     mg/L
# 34746                                   Clorit             0.00     mg/L
# 34747                                 Fluorurs             0.23     mg/L
#
#        OTHERCODE                                  SINONYM SINAC_SENDED
# 0         278888  Comptatge Total de partícules comptades            N
# 1         278888                   Mida de massa més gran            N
# 2         278888                        Mida més abundant            N
# 3         278888           Mida mitjana de les partícules            N
# 4         278888     Quantitat més abundant de partícules            N
# ...          ...                                      ...          ...
# 34743     278888                                  Bromats            N
# 34744     278888                                   Bromur            N
# 34745     278888                                   Clorat            N
# 34746     278888                                   Clorit            N
# 34747     278888                                 Fluorurs            N
#
# [34748 rows x 16 columns]

# %%
eb0_measure_df = raw_eb0_measure_df.copy()

eb0_measure_df["data"] = pd.to_datetime(
    eb0_measure_df["data"], format="%d/%m/%Y"
).dt.date
eb0_measure_df["SAMPDATE"] = pd.to_datetime(
    eb0_measure_df["SAMPDATE"], format="%d/%m/%Y %H:%M:%S"
).dt.time

# %%
eb0_measure_df
# Out:
#        any_   FOLDERNO        data  SAMPDATE   APPRSTS  CLSAMPNO  \
# 0      2018  180002852  2018-07-17  03:00:00  Released  CAMPREDÓ
# 1      2018  180002852  2018-07-17  03:00:00  Released  CAMPREDÓ
# 2      2018  180002852  2018-07-17  03:00:00  Released  CAMPREDÓ
# 3      2018  180002852  2018-07-17  03:00:00  Released  CAMPREDÓ
# 4      2018  180002852  2018-07-17  03:00:00  Released  CAMPREDÓ
# ...     ...        ...         ...       ...       ...       ...
# 34743  2023  230000304  2023-02-06  04:30:00  Released  CAMPREDÓ
# 34744  2023  230000304  2023-02-06  04:30:00  Released  CAMPREDÓ
# 34745  2023  230000304  2023-02-06  04:30:00  Released  CAMPREDÓ
# 34746  2023  230000304  2023-02-06  04:30:00  Released  CAMPREDÓ
# 34747  2023  230000304  2023-02-06  04:30:00  Released  CAMPREDÓ
#
#        ENVSAMPOINTID  PROFILE DISPSTS               TESTNO  \
# 0                320  Default     NaN  Material Particulat
# 1                320  Default     NaN  Material Particulat
# 2                320  Default     NaN  Material Particulat
# 3                320  Default     NaN  Material Particulat
# 4                320  Default     NaN  Material Particulat
# ...              ...      ...     ...                  ...
# 34743            320  Default     NaN        Oxohalogenats
# 34744            320  Default     NaN        Oxohalogenats
# 34745            320  Default     NaN        Oxohalogenats
# 34746            320  Default     NaN        Oxohalogenats
# 34747            320  Default     NaN        Oxohalogenats
#
#                                        ANALYTE  RESULTASNUMERIC    units  \
# 0      Comptatge Total de partícules comptades        103700.00  part/mL
# 1                       Mida de massa més gran            52.00       um
# 2                            Mida més abundant             1.00       um
# 3               Mida mitjana de les partícules             4.00       um
# 4         Quantitat més abundant de partícules         23249.00  part/mL
# ...                                        ...              ...      ...
# 34743                                  Bromats             0.00     µg/L
# 34744                                   Bromur           138.00     µg/L
# 34745                                   Clorat             0.04     mg/L
# 34746                                   Clorit             0.00     mg/L
# 34747                                 Fluorurs             0.23     mg/L
#
#        OTHERCODE                                  SINONYM SINAC_SENDED
# 0         278888  Comptatge Total de partícules comptades            N
# 1         278888                   Mida de massa més gran            N
# 2         278888                        Mida més abundant            N
# 3         278888           Mida mitjana de les partícules            N
# 4         278888     Quantitat més abundant de partícules            N
# ...          ...                                      ...          ...
# 34743     278888                                  Bromats            N
# 34744     278888                                   Bromur            N
# 34745     278888                                   Clorat            N
# 34746     278888                                   Clorit            N
# 34747     278888                                 Fluorurs            N
#
# [34748 rows x 16 columns]

# %%
eb0_measure_features = [
    # 'Alarma Espectral', # ALARMA ESPECTRAL
    "Color",  # COLOR
    "Conductivitat a 20ºC",  # COND
    # 'Ox', # OX
    "Sòlids en suspensió",  # PARTICULES
    "pH",  # PH
    "Mercuri",  # RATIO_HG
    # 'Ratio Terb Sig', # RATIO_TERB_SIG
    # 'Ratio Tlf Uv', # RATIO_TLF_UV
    "Sulfats",  # SULFAT
    "Temperatura",  # TEMP
    # 'Temperatura Aigua', # TEMP_AIGUA
    "Terbolesa",  # TERBOLESA
    # 'Tlf', # TLF
    "Índex UV",  # UV254
    # 'Vis436', # VIS436
    # 'Vis525', # VIS525
    # 'Vis620', # VIS620
]

# %%
eb0_measure_targets = [
    "Clorit",
    "Clorat",
    "Cloroform",
    "Bromodiclorometà",
    "Dibromoclorometà",
    "Bromoform",
    "àcid bromocloroacètic",
    "àcid dibromoacètic",
    "àcid dicloroacètic",
    "àcid monobromoacètic",
    "àcid monocloroacètic",
    "ConnectionErroràcid tricloroacètic",
]

# %%
# Create a new dataframe with only the features of interest, where the name of the features in the list above are in the column 'ANALYTE'
eb0_features_df = eb0_measure_df[
    eb0_measure_df["ANALYTE"].isin(eb0_measure_features)
]

eb0_features_df.drop(
    columns=[
        "any_",
        "FOLDERNO",
        "APPRSTS",
        "CLSAMPNO",
        "DISPSTS",
        "TESTNO",
        "SINONYM",
        "SINAC_SENDED",
    ],
    inplace=True,
)
# Out:
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/2043177473.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb0_features_df.drop(

# %%
eb0_targets_df = eb0_measure_df[
    eb0_measure_df["ANALYTE"].isin(eb0_measure_targets)
]

eb0_targets_df.drop(
    columns=[
        "any_",
        "FOLDERNO",
        "APPRSTS",
        "CLSAMPNO",
        "DISPSTS",
        "TESTNO",
        "SINONYM",
        "SINAC_SENDED",
    ],
    inplace=True,
)
# Out:
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/2168312879.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb0_targets_df.drop(

# %%
eb0_features_df["RESULTASNUMERIC"] = eb0_features_df["RESULTASNUMERIC"].astype(
    float
)
eb0_targets_df["RESULTASNUMERIC"] = eb0_targets_df["RESULTASNUMERIC"].astype(
    float
)
# Out:
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/430557617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb0_features_df["RESULTASNUMERIC"] = eb0_features_df["RESULTASNUMERIC"].astype(
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/430557617.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb0_targets_df["RESULTASNUMERIC"] = eb0_targets_df["RESULTASNUMERIC"].astype(

# %%
eb0_features_df.insert(
    loc=0,
    column="DateTime",
    value=pd.to_datetime(
        eb0_features_df["data"].astype(str)
        + " "
        + eb0_features_df["SAMPDATE"].astype(str)
    ),
)

eb0_targets_df.insert(
    loc=0,
    column="DateTime",
    value=pd.to_datetime(
        eb0_targets_df["data"].astype(str)
        + " "
        + eb0_targets_df["SAMPDATE"].astype(str)
    ),
)

# %%
eb0_features_df.drop(columns=["data", "SAMPDATE"], inplace=True)
eb0_targets_df.drop(columns=["data", "SAMPDATE"], inplace=True)
# Out:
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/2970465721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb0_features_df.drop(columns=["data", "SAMPDATE"], inplace=True)
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/2970465721.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb0_targets_df.drop(columns=["data", "SAMPDATE"], inplace=True)

# %%
eb0_features_df
# Out:
#                  DateTime  ENVSAMPOINTID     PROFILE               ANALYTE  \
# 5     2018-07-17 03:00:00            320     Default   Sòlids en suspensió
# 11    2018-08-06 12:13:00            320     Default   Sòlids en suspensió
# 17    2018-08-20 03:20:00            320     Default   Sòlids en suspensió
# 23    2018-09-03 04:20:00            320     Default   Sòlids en suspensió
# 32    2018-09-10 04:30:00            320  CATPIICv02               Sulfats
# ...                   ...            ...         ...                   ...
# 34736 2023-01-31 03:30:00            320    ADEB0v04  Conductivitat a 20ºC
# 34737 2023-01-31 03:30:00            320    ADEB0v04               Mercuri
# 34739 2023-01-31 03:30:00            320    ADEB0v04                    pH
# 34740 2023-01-31 03:30:00            320    ADEB0v04           Temperatura
# 34741 2023-01-31 03:30:00            320    ADEB0v04             Terbolesa
#
#        RESULTASNUMERIC   units  OTHERCODE
# 5                 24.2    mg/L     278888
# 11                 1.7    mg/L     278888
# 17                 2.5    mg/L     278888
# 23                 2.6    mg/L     278888
# 32               175.0    mg/L     278888
# ...                ...     ...        ...
# 34736           1408.0   µS/cm     278888
# 34737              0.0    µg/L     278888
# 34739              8.4  Und pH     278888
# 34740              9.0      °C     278888
# 34741              1.0     UNF     278888
#
# [7189 rows x 7 columns]

# %%
eb0_targets_df
# Out:
#                  DateTime  ENVSAMPOINTID  PROFILE           ANALYTE  \
# 81    2018-10-01 03:30:00            320  Default            Clorat
# 83    2018-10-01 03:30:00            320  Default            Clorit
# 689   2018-11-05 04:30:00            320  Default  Bromodiclorometà
# 690   2018-11-05 04:30:00            320  Default         Bromoform
# 696   2018-11-05 04:30:00            320  Default            Clorat
# ...                   ...            ...      ...               ...
# 33333 2022-12-07 05:00:00            320  Default            Clorit
# 34008 2023-01-02 04:00:00            320  Default            Clorat
# 34010 2023-01-02 04:00:00            320  Default            Clorit
# 34745 2023-02-06 04:30:00            320  Default            Clorat
# 34746 2023-02-06 04:30:00            320  Default            Clorit
#
#        RESULTASNUMERIC units  OTHERCODE
# 81                0.00  µg/L     278888
# 83                0.00  µg/L     278888
# 689               0.00  µg/L     278888
# 690               0.70  µg/L     278888
# 696              93.00  µg/L     278888
# ...                ...   ...        ...
# 33333             0.00  µg/L     278888
# 34008            33.00  µg/L     278888
# 34010             0.00  µg/L     278888
# 34745             0.04  mg/L     278888
# 34746             0.00  mg/L     278888
#
# [118 rows x 7 columns]

# %% [markdown]
# ### Create DataFrame with one sample per unique DateTime

# %%
eb0_features_df = eb0_features_df.pivot_table(
    index=pd.Grouper(key='DateTime'),
    columns="ANALYTE",
    values="RESULTASNUMERIC"
)

# %%
eb0_features_df
# Out:
# ANALYTE              Color  Conductivitat a 20ºC  Mercuri  Sulfats  \
# DateTime
# 2018-07-17 03:00:00    NaN                   NaN      NaN      NaN
# 2018-08-06 12:13:00    NaN                   NaN      NaN      NaN
# 2018-08-20 03:20:00    NaN                   NaN      NaN      NaN
# 2018-09-03 04:20:00    NaN                   NaN      NaN      NaN
# 2018-09-10 04:30:00    NaN                   NaN      NaN    175.0
# ...                    ...                   ...      ...      ...
# 2023-01-26 04:00:00    5.3                1513.0      0.0      NaN
# 2023-01-27 04:00:00    5.2                1505.0      0.0      NaN
# 2023-01-28 04:30:00    NaN                1482.0      0.0      NaN
# 2023-01-30 04:30:00    6.0                1435.0      0.0      NaN
# 2023-01-31 03:30:00    5.4                1408.0      0.0      NaN
#
# ANALYTE              Sòlids en suspensió  Temperatura  Terbolesa   pH  \
# DateTime
# 2018-07-17 03:00:00                 24.2          NaN        NaN  NaN
# 2018-08-06 12:13:00                  1.7          NaN        NaN  NaN
# 2018-08-20 03:20:00                  2.5          NaN        NaN  NaN
# 2018-09-03 04:20:00                  2.6          NaN        NaN  NaN
# 2018-09-10 04:30:00                  NaN          NaN        NaN  NaN
# ...                                  ...          ...        ...  ...
# 2023-01-26 04:00:00                  NaN         12.9        0.9  8.3
# 2023-01-27 04:00:00                  NaN         12.6        0.9  8.3
# 2023-01-28 04:30:00                  NaN          9.9        0.9  8.3
# 2023-01-30 04:30:00                  NaN          9.7        1.1  8.3
# 2023-01-31 03:30:00                  NaN          9.0        1.0  8.4
#
# ANALYTE              Índex UV
# DateTime
# 2018-07-17 03:00:00       NaN
# 2018-08-06 12:13:00       NaN
# 2018-08-20 03:20:00       NaN
# 2018-09-03 04:20:00       NaN
# 2018-09-10 04:30:00       NaN
# ...                       ...
# 2023-01-26 04:00:00       NaN
# 2023-01-27 04:00:00       NaN
# 2023-01-28 04:30:00       NaN
# 2023-01-30 04:30:00       NaN
# 2023-01-31 03:30:00       NaN
#
# [1385 rows x 9 columns]

# %%
eb0_targets_df = eb0_targets_df.pivot_table(
    index=pd.Grouper(key='DateTime'),
    columns="ANALYTE",
    values="RESULTASNUMERIC",
)

# %%
eb0_targets_df
# Out:
# ANALYTE              Bromodiclorometà  Bromoform  Clorat  Clorit  Cloroform  \
# DateTime
# 2018-10-01 03:30:00               NaN        NaN    0.00     0.0        NaN
# 2018-11-05 04:30:00               0.0        0.7   93.00     0.0        0.0
# 2018-12-03 04:15:00               NaN        NaN  132.00     0.0        NaN
# 2019-01-07 04:25:00               NaN        NaN   49.00     0.0        NaN
# 2019-02-04 03:00:00               NaN        NaN   65.00     0.0        NaN
# 2019-02-18 04:00:00               0.0        0.0     NaN     NaN        0.0
# 2019-03-04 04:00:00               NaN        NaN    0.00     0.0        NaN
# 2019-04-01 04:20:00               NaN        NaN   38.00     0.0        NaN
# 2019-05-06 04:45:00               NaN        NaN   72.00     0.0        NaN
# 2019-06-03 04:30:00               NaN        NaN   55.00     0.0        NaN
# 2019-07-01 04:30:00               NaN        NaN   47.00     0.0        NaN
# 2019-07-15 04:30:00               0.0        0.0     NaN     NaN        0.0
# 2019-08-05 04:18:00               NaN        NaN  107.00     0.0        NaN
# 2019-09-02 03:30:00               NaN        NaN    0.00     0.0        NaN
# 2019-10-07 04:20:00               NaN        NaN    0.00     0.0        NaN
# 2019-11-04 04:00:00               NaN        NaN    0.00     0.0        NaN
# 2019-12-02 04:45:00               NaN        NaN    0.00     0.0        NaN
# 2020-01-07 04:50:00               NaN        NaN    0.00     0.0        NaN
# 2020-02-03 03:40:00               NaN        NaN    0.00     0.0        NaN
# 2020-03-02 04:30:00               NaN        NaN   38.00     0.0        NaN
# 2020-04-06 03:00:00               NaN        NaN   37.00     0.0        NaN
# 2020-05-04 05:30:00               NaN        NaN    0.00     0.0        NaN
# 2020-06-01 03:20:00               NaN        NaN   20.00     0.0        NaN
# 2020-07-06 04:15:00               NaN        NaN    0.00     0.0        NaN
# 2020-08-03 04:15:00               NaN        NaN    0.00     0.0        NaN
# 2020-09-07 04:15:00               NaN        NaN    0.00     0.0        NaN
# 2020-10-05 03:20:00               NaN        NaN    0.00     0.0        NaN
# 2020-11-02 04:00:00               NaN        NaN    0.00     0.0        NaN
# 2020-12-02 03:50:00               NaN        NaN    0.00     0.0        NaN
# 2021-01-04 05:00:00               NaN        NaN    0.00     0.0        NaN
# 2021-02-01 04:10:00               NaN        NaN    0.00     0.0        NaN
# 2021-03-01 03:15:00               NaN        NaN    0.00     0.0        NaN
# 2021-04-06 04:25:00               NaN        NaN    0.00     0.0        NaN
# 2021-05-03 04:00:00               NaN        NaN    0.00     0.0        NaN
# 2021-06-07 04:05:00               NaN        NaN    0.00     0.0        NaN
# 2021-07-05 04:00:00               NaN        NaN    0.00     0.0        NaN
# 2021-08-02 04:10:00               NaN        NaN    0.00     0.0        NaN
# 2021-09-06 04:00:00               NaN        NaN   26.00     0.0        NaN
# 2021-10-04 04:30:00               NaN        NaN   22.00     0.0        NaN
# 2021-11-02 03:45:00               NaN        NaN   39.00     0.0        NaN
# 2021-12-01 04:12:00               NaN        NaN   75.00     0.0        NaN
# 2022-01-04 03:30:00               NaN        NaN   51.00     5.0        NaN
# 2022-02-07 04:45:00               NaN        NaN    5.00     4.0        NaN
# 2022-03-07 04:00:00               NaN        NaN   19.00     0.0        NaN
# 2022-04-04 08:00:00               NaN        NaN   27.00     0.0        NaN
# 2022-05-02 04:45:00               NaN        NaN   36.00     0.0        NaN
# 2022-06-07 04:15:00               NaN        NaN   29.00     0.0        NaN
# 2022-07-04 04:27:00               NaN        NaN   26.00     0.0        NaN
# 2022-08-01 04:15:00               NaN        NaN   11.00     0.0        NaN
# 2022-09-05 05:10:00               NaN        NaN    0.00     0.0        NaN
# 2022-10-03 04:00:00               NaN        NaN   22.00     0.0        NaN
# 2022-11-07 04:20:00               NaN        NaN   29.00     0.0        NaN
# 2022-12-07 05:00:00               NaN        NaN   34.00     0.0        NaN
# 2023-01-02 04:00:00               NaN        NaN   33.00     0.0        NaN
# 2023-02-06 04:30:00               NaN        NaN    0.04     0.0        NaN
#
# ANALYTE              Dibromoclorometà
# DateTime
# 2018-10-01 03:30:00               NaN
# 2018-11-05 04:30:00               0.3
# 2018-12-03 04:15:00               NaN
# 2019-01-07 04:25:00               NaN
# 2019-02-04 03:00:00               NaN
# 2019-02-18 04:00:00               0.0
# 2019-03-04 04:00:00               NaN
# 2019-04-01 04:20:00               NaN
# 2019-05-06 04:45:00               NaN
# 2019-06-03 04:30:00               NaN
# 2019-07-01 04:30:00               NaN
# 2019-07-15 04:30:00               0.0
# 2019-08-05 04:18:00               NaN
# 2019-09-02 03:30:00               NaN
# 2019-10-07 04:20:00               NaN
# 2019-11-04 04:00:00               NaN
# 2019-12-02 04:45:00               NaN
# 2020-01-07 04:50:00               NaN
# 2020-02-03 03:40:00               NaN
# 2020-03-02 04:30:00               NaN
# 2020-04-06 03:00:00               NaN
# 2020-05-04 05:30:00               NaN
# 2020-06-01 03:20:00               NaN
# 2020-07-06 04:15:00               NaN
# 2020-08-03 04:15:00               NaN
# 2020-09-07 04:15:00               NaN
# 2020-10-05 03:20:00               NaN
# 2020-11-02 04:00:00               NaN
# 2020-12-02 03:50:00               NaN
# 2021-01-04 05:00:00               NaN
# 2021-02-01 04:10:00               NaN
# 2021-03-01 03:15:00               NaN
# 2021-04-06 04:25:00               NaN
# 2021-05-03 04:00:00               NaN
# 2021-06-07 04:05:00               NaN
# 2021-07-05 04:00:00               NaN
# 2021-08-02 04:10:00               NaN
# 2021-09-06 04:00:00               NaN
# 2021-10-04 04:30:00               NaN
# 2021-11-02 03:45:00               NaN
# 2021-12-01 04:12:00               NaN
# 2022-01-04 03:30:00               NaN
# 2022-02-07 04:45:00               NaN
# 2022-03-07 04:00:00               NaN
# 2022-04-04 08:00:00               NaN
# 2022-05-02 04:45:00               NaN
# 2022-06-07 04:15:00               NaN
# 2022-07-04 04:27:00               NaN
# 2022-08-01 04:15:00               NaN
# 2022-09-05 05:10:00               NaN
# 2022-10-03 04:00:00               NaN
# 2022-11-07 04:20:00               NaN
# 2022-12-07 05:00:00               NaN
# 2023-01-02 04:00:00               NaN
# 2023-02-06 04:30:00               NaN

# %%
eb0_features_df.dropna(how="all", inplace=True)
eb0_targets_df.dropna(how="all", inplace=True)

# %%
eb0_min_date = eb0_features_df.index.min()
eb0_max_date = eb0_features_df.index.max()

# %%
eb0_features_df.to_excel(
    os.path.join(clean_data_path, "EB0_Features_Lab.xlsx")
)

eb0_targets_df.to_excel(
    os.path.join(clean_data_path, "EB0_Targets_Lab.xlsx")
)

# %% [markdown]
# ## EB1

# %%
raw_eb1_measure_df
# Out:
#        any_   FOLDERNO        data            SAMPDATE   APPRSTS  \
# 0      2017  170000094  15/05/2017 2017-05-15 07:40:00  Released
# 1      2017  170000048  15/05/2017 2017-05-15 07:40:00  Released
# 2      2017  170000048  15/05/2017 2017-05-15 07:40:00  Released
# 3      2017  170000008  15/05/2017 2017-05-15 07:40:00  Released
# 4      2017  170000053  15/05/2017 2017-05-15 07:40:00  Released
# ...     ...        ...         ...                 ...       ...
# 70946  2023  230000238  30/01/2023 2023-01-30 08:25:00  Released
# 70947  2023  230000238  30/01/2023 2023-01-30 08:25:00  Released
# 70948  2023  230000251  30/01/2023 2023-01-30 08:25:00  Released
# 70949  2023  230000251  30/01/2023 2023-01-30 08:25:00  Released
# 70950  2023  230000225  30/01/2023 2023-01-30 08:25:00  Released
#
#                      CLSAMPNO  ENVSAMPOINTID              PROFILE DISPSTS  \
# 0      SORTIDA ETAP EB1 ZA-PR            187              PRQtots     NaN
# 1      SORTIDA ETAP EB1 ZA-PR            187               CATPII     NaN
# 2      SORTIDA ETAP EB1 ZA-PR            187               CATPII     NaN
# 3      SORTIDA ETAP EB1 ZA-PR            187               ACNEB1     NaN
# 4      SORTIDA ETAP EB1 ZA-PR            187              Default     NaN
# ...                       ...            ...                  ...     ...
# 70946  SORTIDA ETAP EB1 ZA-PR            187              Default     NaN
# 70947  SORTIDA ETAP EB1 ZA-PR            187              Default     NaN
# 70948  SORTIDA ETAP EB1 ZA-PR            187  PEST EB1-GCMS/MSv01     NaN
# 70949  SORTIDA ETAP EB1 ZA-PR            187  PEST EB1-GCMS/MSv01     NaN
# 70950  SORTIDA ETAP EB1 ZA-PR            187            ACNEB1v07     NaN
#
#                          TESTNO                  ANALYTE  RESULTASNUMERIC  \
# 0                  Radioisòtops               Actini-228            0.000
# 1                           TAC  Alcalinitat (CaCO3) TAC          153.000
# 2                            TA         Alcalinitat (TA)            0.000
# 3                       Metalls                  Alumini           41.000
# 4                     Triazines                  Ametrin            0.000
# ...                         ...                      ...              ...
# 70946                 Triazines            Terbutilazina            0.007
# 70947                 Triazines               Terbutrina            0.000
# 70948  Semivolàtils per GC-MSMS           Trifenilfosfat            0.000
# 70949  Semivolàtils per GC-MSMS              Trifluralin            0.000
# 70950                   Metalls                    Urani            5.000
#
#        units  OTHERCODE                  SINONYM SINAC_SENDED
# 0      Bq/Kg     173219               Actini-228            Y
# 1       mg/L     173219  Alcalinitat (CaCO3) TAC            N
# 2       mg/L     173219         Alcalinitat (TA)            N
# 3       µg/L     173219                  Alumini            Y
# 4       µg/L     173219                  Ametrin            Y
# ...      ...        ...                      ...          ...
# 70946   µg/L     173219            Terbutilazina            N
# 70947   µg/L     173219               Terbutrina            N
# 70948   µg/L     173219           Trifenilfosfat            N
# 70949   µg/L     173219              Trifluralin            N
# 70950   µg/L     173219                    Urani            N
#
# [70951 rows x 16 columns]

# %%
eb1_measure_df = raw_eb1_measure_df.copy()

eb1_measure_df["data"] = pd.to_datetime(
    eb1_measure_df["data"], format="%d/%m/%Y"
).dt.date
eb1_measure_df["SAMPDATE"] = pd.to_datetime(
    eb1_measure_df["SAMPDATE"], format="%d/%m/%Y %H:%M:%S"
).dt.time

# %%
eb1_measure_df
# Out:
#        any_   FOLDERNO        data  SAMPDATE   APPRSTS  \
# 0      2017  170000094  2017-05-15  07:40:00  Released
# 1      2017  170000048  2017-05-15  07:40:00  Released
# 2      2017  170000048  2017-05-15  07:40:00  Released
# 3      2017  170000008  2017-05-15  07:40:00  Released
# 4      2017  170000053  2017-05-15  07:40:00  Released
# ...     ...        ...         ...       ...       ...
# 70946  2023  230000238  2023-01-30  08:25:00  Released
# 70947  2023  230000238  2023-01-30  08:25:00  Released
# 70948  2023  230000251  2023-01-30  08:25:00  Released
# 70949  2023  230000251  2023-01-30  08:25:00  Released
# 70950  2023  230000225  2023-01-30  08:25:00  Released
#
#                      CLSAMPNO  ENVSAMPOINTID              PROFILE DISPSTS  \
# 0      SORTIDA ETAP EB1 ZA-PR            187              PRQtots     NaN
# 1      SORTIDA ETAP EB1 ZA-PR            187               CATPII     NaN
# 2      SORTIDA ETAP EB1 ZA-PR            187               CATPII     NaN
# 3      SORTIDA ETAP EB1 ZA-PR            187               ACNEB1     NaN
# 4      SORTIDA ETAP EB1 ZA-PR            187              Default     NaN
# ...                       ...            ...                  ...     ...
# 70946  SORTIDA ETAP EB1 ZA-PR            187              Default     NaN
# 70947  SORTIDA ETAP EB1 ZA-PR            187              Default     NaN
# 70948  SORTIDA ETAP EB1 ZA-PR            187  PEST EB1-GCMS/MSv01     NaN
# 70949  SORTIDA ETAP EB1 ZA-PR            187  PEST EB1-GCMS/MSv01     NaN
# 70950  SORTIDA ETAP EB1 ZA-PR            187            ACNEB1v07     NaN
#
#                          TESTNO                  ANALYTE  RESULTASNUMERIC  \
# 0                  Radioisòtops               Actini-228            0.000
# 1                           TAC  Alcalinitat (CaCO3) TAC          153.000
# 2                            TA         Alcalinitat (TA)            0.000
# 3                       Metalls                  Alumini           41.000
# 4                     Triazines                  Ametrin            0.000
# ...                         ...                      ...              ...
# 70946                 Triazines            Terbutilazina            0.007
# 70947                 Triazines               Terbutrina            0.000
# 70948  Semivolàtils per GC-MSMS           Trifenilfosfat            0.000
# 70949  Semivolàtils per GC-MSMS              Trifluralin            0.000
# 70950                   Metalls                    Urani            5.000
#
#        units  OTHERCODE                  SINONYM SINAC_SENDED
# 0      Bq/Kg     173219               Actini-228            Y
# 1       mg/L     173219  Alcalinitat (CaCO3) TAC            N
# 2       mg/L     173219         Alcalinitat (TA)            N
# 3       µg/L     173219                  Alumini            Y
# 4       µg/L     173219                  Ametrin            Y
# ...      ...        ...                      ...          ...
# 70946   µg/L     173219            Terbutilazina            N
# 70947   µg/L     173219               Terbutrina            N
# 70948   µg/L     173219           Trifenilfosfat            N
# 70949   µg/L     173219              Trifluralin            N
# 70950   µg/L     173219                    Urani            N
#
# [70951 rows x 16 columns]

# %%
eb1_measure_features = [
    # 'Alarma Spectral', # ALARMA SPECTRAL
    "Clor lliure residual",  # CLOR LLIURE
    "Color",  # COLOR
    "Conductivitat a 20ºC",  # COND
    # 'DOC', # DOC
    # 'ORP', # ORP
    "Sòlids en suspensió",  # PARTICULES
    "pH",  # PH
    "Temperatura",  # TEMP
    "Terbolesa",  # TERBOLESA SCAN
    # 'Tlf', # TLF
    "Carboni Orgànic Total Tractament",  # TOC
    "Índex UV",  # UV254
    # 'Vis436', # VIS436
    # 'Vis525', # VIS525
    # 'Vis620', # VIS620
]

# %%
eb1_measure_targets = [
    "Clorit",
    "Clorat",
    "Cloroform",
    "Bromodiclorometà",
    "Dibromoclorometà",
    "Bromoform",
    "àcid bromocloroacètic",
    "àcid dibromoacètic",
    "àcid dicloroacètic",
    "àcid monobromoacètic",
    "àcid monocloroacètic",
    "ConnectionErroràcid tricloroacètic",
]

# %%
eb1_features_df = eb1_measure_df[
    eb1_measure_df["ANALYTE"].isin(eb1_measure_features)
]

eb1_features_df.drop(
    columns=[
        "any_",
        "FOLDERNO",
        "APPRSTS",
        "CLSAMPNO",
        "DISPSTS",
        "TESTNO",
        "SINONYM",
        "SINAC_SENDED",
    ],
    inplace=True,
)
# Out:
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/1978529070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb1_features_df.drop(

# %%
eb1_targets_df = eb1_measure_df[
    eb1_measure_df["ANALYTE"].isin(eb1_measure_targets)
]

eb1_targets_df.drop(
    columns=[
        "any_",
        "FOLDERNO",
        "APPRSTS",
        "CLSAMPNO",
        "DISPSTS",
        "TESTNO",
        "SINONYM",
        "SINAC_SENDED",
    ],
    inplace=True,
)
# Out:
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/3436139006.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb1_targets_df.drop(

# %%
eb1_features_df["RESULTASNUMERIC"] = eb1_features_df["RESULTASNUMERIC"].astype(
    float
)
eb1_targets_df["RESULTASNUMERIC"] = eb1_targets_df["RESULTASNUMERIC"].astype(
    float
)
# Out:
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/1218830866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb1_features_df["RESULTASNUMERIC"] = eb1_features_df["RESULTASNUMERIC"].astype(
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/1218830866.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb1_targets_df["RESULTASNUMERIC"] = eb1_targets_df["RESULTASNUMERIC"].astype(

# %%
eb1_features_df.insert(
    loc=0,
    column="DateTime",
    value=pd.to_datetime(
        eb1_features_df["data"].astype(str)
        + " "
        + eb1_features_df["SAMPDATE"].astype(str)
    ),
)

eb1_targets_df.insert(
    loc=0,
    column="DateTime",
    value=pd.to_datetime(
        eb1_targets_df["data"].astype(str)
        + " "
        + eb1_targets_df["SAMPDATE"].astype(str)
    ),
)

# %%
eb1_features_df.drop(columns=["data", "SAMPDATE"], inplace=True)
eb1_targets_df.drop(columns=["data", "SAMPDATE"], inplace=True)
# Out:
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/2941113448.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb1_features_df.drop(columns=["data", "SAMPDATE"], inplace=True)
# /var/folders/z5/plf0_b5s39nb0_gctbxmpndc0000gn/T/ipykernel_41883/2941113448.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eb1_targets_df.drop(columns=["data", "SAMPDATE"], inplace=True)

# %%
eb1_features_df
# Out:
#                  DateTime  ENVSAMPOINTID    PROFILE               ANALYTE  \
# 21    2017-05-15 07:40:00            187     ACNEB1  Clor lliure residual
# 27    2017-05-15 07:40:00            187     ACNEB1                 Color
# 28    2017-05-15 07:40:00            187     ACNEB1  Conductivitat a 20ºC
# 52    2017-05-15 07:40:00            187     ACNEB1                    pH
# 72    2017-05-15 07:40:00            187     ACNEB1             Terbolesa
# ...                   ...            ...        ...                   ...
# 70880 2023-01-30 08:25:00            187  ACNEB1v07                 Color
# 70881 2023-01-30 08:25:00            187  ACNEB1v07  Conductivitat a 20ºC
# 70932 2023-01-30 08:25:00            187  ACNEB1v07                    pH
# 70944 2023-01-30 08:25:00            187  ACNEB1v07           Temperatura
# 70945 2023-01-30 08:25:00            187  ACNEB1v07             Terbolesa
#
#        RESULTASNUMERIC       units  OTHERCODE
# 21                1.20        mg/L     173219
# 27                0.00  mg Pt-Co/L     173219
# 28              852.00       µS/cm     173219
# 52                7.70      Und pH     173219
# 72                0.00         UNF     173219
# ...                ...         ...        ...
# 70880             0.10  mg Pt-Co/L     173219
# 70881          1467.00       µS/cm     173219
# 70932             7.70      Und pH     173219
# 70944            10.70          °C     173219
# 70945             0.14         UNF     173219
#
# [10765 rows x 7 columns]

# %%
eb1_targets_df
# Out:
#                  DateTime  ENVSAMPOINTID  PROFILE                ANALYTE  \
# 13    2017-05-15 07:40:00            187  Default       Bromodiclorometà
# 14    2017-05-15 07:40:00            187  Default              Bromoform
# 22    2017-05-15 07:40:00            187  Default              Cloroform
# 32    2017-05-15 07:40:00            187  Default       Dibromoclorometà
# 198   2017-05-22 07:15:00            187   CATPCP  àcid bromocloroacètic
# ...                   ...            ...      ...                    ...
# 70551 2023-01-16 08:35:00            187  Default              Bromoform
# 70557 2023-01-16 08:35:00            187  Default                 Clorat
# 70558 2023-01-16 08:35:00            187  Default                 Clorit
# 70559 2023-01-16 08:35:00            187  Default              Cloroform
# 70568 2023-01-16 08:35:00            187  Default       Dibromoclorometà
#
#        RESULTASNUMERIC units  OTHERCODE
# 13                 0.0  µg/L     173219
# 14                 0.0  µg/L     173219
# 22                 0.0  µg/L     173219
# 32                 0.0  µg/L     173219
# 198                1.3  µg/L     173219
# ...                ...   ...        ...
# 70551              3.9  µg/L     173219
# 70557            132.0  µg/L     173219
# 70558              0.0  µg/L     173219
# 70559              0.0  µg/L     173219
# 70568              3.6  µg/L     173219
#
# [2140 rows x 7 columns]

# %% [markdown]
# ### Create DataFrame with one sample per unique DateTime

# %%
eb1_features_df = eb1_features_df.pivot_table(
    index=pd.Grouper(key='DateTime'),
    columns="ANALYTE",
    values="RESULTASNUMERIC"
)

# %%
eb1_features_df
# Out:
# ANALYTE              Carboni Orgànic Total Tractament  Clor lliure residual  \
# DateTime
# 2017-05-15 07:40:00                               NaN                  1.20
# 2017-05-16 07:45:00                               NaN                  0.91
# 2017-05-17 07:30:00                               NaN                  1.25
# 2017-05-18 07:30:00                               NaN                  1.04
# 2017-05-19 07:30:00                               NaN                  1.36
# ...                                               ...                   ...
# 2023-01-24 08:25:00                               NaN                  0.88
# 2023-01-25 08:30:00                               NaN                  0.87
# 2023-01-26 08:30:00                               NaN                  0.83
# 2023-01-28 08:55:00                               NaN                  0.84
# 2023-01-30 08:25:00                               NaN                  0.90
#
# ANALYTE              Color  Conductivitat a 20ºC  Sòlids en suspensió  \
# DateTime
# 2017-05-15 07:40:00    0.0                 852.0                  NaN
# 2017-05-16 07:45:00    0.0                 857.0                  NaN
# 2017-05-17 07:30:00    0.0                 866.0                  NaN
# 2017-05-18 07:30:00    0.0                 863.0                  NaN
# 2017-05-19 07:30:00    0.0                 830.0                  NaN
# ...                    ...                   ...                  ...
# 2023-01-24 08:25:00    0.1                1552.0                  NaN
# 2023-01-25 08:30:00    0.0                1539.0                  NaN
# 2023-01-26 08:30:00    0.1                1528.0                  NaN
# 2023-01-28 08:55:00    0.5                1524.0                  NaN
# 2023-01-30 08:25:00    0.1                1467.0                  NaN
#
# ANALYTE              Temperatura  Terbolesa   pH  Índex UV
# DateTime
# 2017-05-15 07:40:00          NaN       0.00  7.7       NaN
# 2017-05-16 07:45:00          NaN       0.00  7.7       NaN
# 2017-05-17 07:30:00          NaN       0.00  7.7       NaN
# 2017-05-18 07:30:00          NaN       0.00  8.0       NaN
# 2017-05-19 07:30:00          NaN       0.20  7.6       NaN
# ...                          ...        ...  ...       ...
# 2023-01-24 08:25:00          9.9       0.12  7.7       NaN
# 2023-01-25 08:30:00          9.9       0.12  7.9       NaN
# 2023-01-26 08:30:00         10.1       0.13  7.7       NaN
# 2023-01-28 08:55:00         12.2       0.19  7.7       NaN
# 2023-01-30 08:25:00         10.7       0.14  7.7       NaN
#
# [2075 rows x 9 columns]

# %%
eb1_targets_df = eb1_targets_df.pivot_table(
    index=pd.Grouper(key='DateTime'),
    columns="ANALYTE",
    values="RESULTASNUMERIC",
)

# %%
eb1_targets_df
# Out:
# ANALYTE              Bromodiclorometà  Bromoform  Clorat  Clorit  Cloroform  \
# DateTime
# 2017-05-15 07:40:00               0.0        0.0     NaN     NaN        0.0
# 2017-05-22 07:15:00               0.0        2.7     0.0     0.0        0.0
# 2017-05-29 07:00:00               3.3        3.3     NaN     NaN        2.1
# 2017-06-05 07:30:00               2.2        2.5     NaN     0.0        1.7
# 2017-06-12 07:40:00               0.0        2.7     NaN     NaN        0.0
# ...                               ...        ...     ...     ...        ...
# 2022-12-19 06:45:00               0.0        4.0   127.0     0.0        0.0
# 2022-12-27 07:00:00               0.0        5.3     NaN     NaN        0.0
# 2023-01-02 06:55:00               0.0        4.0   136.0     0.0        0.0
# 2023-01-09 08:30:00               0.0        3.6     NaN     NaN        0.0
# 2023-01-16 08:35:00               0.0        3.9   132.0     0.0        0.0
#
# ANALYTE              Dibromoclorometà  àcid bromocloroacètic  \
# DateTime
# 2017-05-15 07:40:00               0.0                    NaN
# 2017-05-22 07:15:00               4.9                    1.3
# 2017-05-29 07:00:00               7.2                    NaN
# 2017-06-05 07:30:00               5.3                    1.3
# 2017-06-12 07:40:00               3.8                    NaN
# ...                               ...                    ...
# 2022-12-19 06:45:00               4.1                    0.8
# 2022-12-27 07:00:00               5.4                    NaN
# 2023-01-02 06:55:00               4.3                    0.9
# 2023-01-09 08:30:00               3.6                    NaN
# 2023-01-16 08:35:00               3.6                    0.7
#
# ANALYTE              àcid dibromoacètic  àcid dicloroacètic  \
# DateTime
# 2017-05-15 07:40:00                 NaN                 NaN
# 2017-05-22 07:15:00                 1.7                 0.8
# 2017-05-29 07:00:00                 NaN                 NaN
# 2017-06-05 07:30:00                 1.7                 0.7
# 2017-06-12 07:40:00                 NaN                 NaN
# ...                                 ...                 ...
# 2022-12-19 06:45:00                 2.2                 0.0
# 2022-12-27 07:00:00                 NaN                 NaN
# 2023-01-02 06:55:00                 2.3                 0.0
# 2023-01-09 08:30:00                 NaN                 NaN
# 2023-01-16 08:35:00                 2.3                 0.0
#
# ANALYTE              àcid monobromoacètic  àcid monocloroacètic
# DateTime
# 2017-05-15 07:40:00                   NaN                   NaN
# 2017-05-22 07:15:00                   0.0                   0.0
# 2017-05-29 07:00:00                   NaN                   NaN
# 2017-06-05 07:30:00                   0.0                   0.0
# 2017-06-12 07:40:00                   NaN                   NaN
# ...                                   ...                   ...
# 2022-12-19 06:45:00                   0.0                   0.0
# 2022-12-27 07:00:00                   NaN                   NaN
# 2023-01-02 06:55:00                   0.0                   0.0
# 2023-01-09 08:30:00                   NaN                   NaN
# 2023-01-16 08:35:00                   0.0                   0.0
#
# [303 rows x 11 columns]

# %%
eb1_features_df.dropna(how="all", inplace=True)
eb1_targets_df.dropna(how="all", inplace=True)

# %%
eb1_min_date = eb1_features_df.index.min()
eb1_max_date = eb1_features_df.index.max()

# %%
eb1_features_df.to_excel(
    os.path.join(clean_data_path, "EB1_Features_Lab.xlsx")
)

eb1_targets_df.to_excel(
    os.path.join(clean_data_path, "EB1_Targets_Lab.xlsx")
)

# %% [markdown]
# # Online Sensors Reading

# %%
def load_data_from_folder(folder_path):
    df_dict = {}
    for filename in os.listdir(folder_path):
        f = os.path.join(folder_path, filename)
        if os.path.isfile(f):
            if not filename.startswith("."):
                if filename.endswith(".csv"):
                    with open(os.path.join(folder_path, filename), "r") as file:
                        lines = file.readlines()

                        corrected_lines = []
                        line_iter = iter(lines)
                        max_len = 0
                        for line in line_iter:
                            if len(line.split(";")) > max_len:
                                max_len = len(line.split(";"))

                            if len(line.split(";")) < max_len:
                                try:
                                    line = line + next(line_iter)
                                except StopIteration:
                                    pass

                            if "n/a;\n" in line:
                                if not line.endswith("n/a;\n"):
                                    line = line.replace("n/a;\n", "n/a;")
                                    line = line.rstrip(";\n") + "\n"
                                else:
                                    line = line.replace("n/a;\n", "n/a;")
                                    line = line.rstrip(";") + "\n"
                            else:
                                line = line.rstrip(";\n") + "\n"

                            corrected_lines.append(line)

                        # Write the corrected lines to a new file
                        corrected_file = os.path.join(folder_path, filename)
                        with open(corrected_file, "w") as file:
                            file.writelines(corrected_lines)

                    # Load the corrected file with pandas
                    df = pd.read_csv(corrected_file, sep=";", na_filter=False)
                elif filename.endswith(".xlsx"):
                    df = pd.read_excel(f)
                else:
                    raise Exception("File format not supported")
                df_dict[pathlib.Path(filename).stem] = df
    return df_dict

# %% [markdown]
# ## EB0 online sensor readings

# %%
raw_eb0_sensor_df_dict = load_data_from_folder(eb0_sensor_path)

# %%
new_dict = {}
for key in deepcopy(raw_eb0_sensor_df_dict).keys():
    new_key = key.partition("_")[2].upper()
    new_dict[new_key] = deepcopy(raw_eb0_sensor_df_dict).pop(key)
raw_eb0_sensor_df_dict = new_dict

# %%
raw_eb0_sensor_df_dict.keys()
# Out:
# dict_keys(['UV254', 'RATIO_TLF_UV', 'VIS525', 'TLF', 'VIS620', 'SULFAT', 'VIS436', 'PARTICULES', 'ALARMA ESPECTRAL', 'TERBOLESA', 'COND', 'PH', 'COLOR', 'RATIO_TERB_SIG', 'TEMP_AIGUA', 'OX', 'TEMP', 'RATIO_HG'])

# %%
raw_eb0_sensor_df_dict["COND"]
# Out:
#              Fecha      HORA CPB00_CTR_M01_PV                  \
# 0       01/01/2022  00:00:00                          0,00000
# 1       01/01/2022  00:05:00                          0,00000
# 2       01/01/2022  00:10:00                          0,00000
# 3       01/01/2022  00:15:00                          0,00000
# 4       01/01/2022  00:20:00                          0,00000
# ...            ...       ...                              ...
# 108463  12/01/2023  14:35:00                       1602,40000
# 108464  12/01/2023  14:40:00                       1602,61667
# 108465  12/01/2023  14:45:00                       1602,30000
# 108466  12/01/2023  14:50:00                       1602,96667
# 108467  12/01/2023  14:55:00                       1603,01667
#
#        CPB00_CTR_M01_VM                 CPB00_CTR_M01_VA                  \
# 0                               0,00000                          0,00000
# 1                               0,00000                          0,00000
# 2                               0,00000                          0,00000
# 3                               0,00000                          0,00000
# 4                               0,00000                          0,00000
# ...                                 ...                              ...
# 108463                          0,00000                          0,00000
# 108464                          0,00000                          0,00000
# 108465                          0,00000                          0,00000
# 108466                          0,00000                          0,00000
# 108467                          0,00000                          0,00000
#
#        CPB00_ASU_M01_PV
# 0                               0,00000
# 1                               0,00000
# 2                               0,00000
# 3                               0,00000
# 4                               0,00000
# ...                                 ...
# 108463                        400,66667
# 108464                        400,60417
# 108465                        400,59583
# 108466                        400,78333
# 108467                        400,73750
#
# [108468 rows x 6 columns]

# %%
eb0_sensor_df_dict = deepcopy(raw_eb0_sensor_df_dict)

# %%
for key, item in eb0_sensor_df_dict.items():
    item["Fecha"] = pd.to_datetime(item["Fecha"], format="%d/%m/%Y").dt.date
    item["HORA"] = pd.to_datetime(item["HORA"], format="%H:%M:%S").dt.time
    item.insert(
        loc=0,
        column="DateTime",
        value=pd.to_datetime(
            item["Fecha"].astype(str) + " " + item["HORA"].astype(str)
        ),
    )
    item.drop(columns=["Fecha", "HORA"], inplace=True)
    for col in item.columns[1:]:
        item[col] = item[col].replace("n/a", None, regex=True)
        item.dropna(inplace=True)
        item[col] = item[col].replace(",", ".", regex=True)
        item[col] = item[col].astype(float)
        
    eb0_sensor_df_dict[key] = item[(item["DateTime"] >= eb0_min_date) & (item["DateTime"] <= eb0_max_date)]

# %%
# the column that contains the measured value is the first one containing _PV
# rename it with the name of the measured parameter
for key, item in eb0_sensor_df_dict.items():
    for col in item.columns:
        if "_PV" in col:
            item.rename(columns={col: key}, inplace=True)
            break

# %%
# a sample is considered valid if the columns after the one containing the measured value (the second one) are all equal to 0
# if not, the sample is considered invalid and is dropped
for key, item in eb0_sensor_df_dict.items():
    # Select the columns after the second one that contain '_VM', 'VA' and 'F1' and check if all values are equal to 0
    selected_columns = item.columns[2:].tolist()
    filtered_columns = item.filter(selected_columns).filter(like='_VM').columns.tolist() + item.filter(selected_columns).filter(like='VA').columns.tolist() + item.filter(selected_columns).filter(like='F1').columns.tolist()
    
    
    mask = (item[filtered_columns] != 0).any(axis=1)
    
    # Drop the rows where the mask is True
    item.drop(item[mask].index, inplace=True)
    
    # Drop the columns after the second one
    item.drop(columns=item.columns[2:], inplace=True)

# %%
# get the median sampling rate for each sensor to retrieve the most frequent sampling rate
sampling_rates = {}
for key, item in eb0_sensor_df_dict.items():
    sampling_rates[key] = item["DateTime"].diff().median()

# get the most frequent sampling rate
sampling_rate = max(set(sampling_rates.values()), key=list(sampling_rates.values()).count)

# resample the dataframes to the most frequent sampling rate
for key, item in eb0_sensor_df_dict.items():
    item.set_index("DateTime", inplace=True)
    item = item[~item.index.duplicated(keep='first')]
    item = item.resample(sampling_rate).interpolate(method="time")
    item.reset_index(inplace=True)
    eb0_sensor_df_dict[key] = item

# %%
# Initialize the final DataFrame with the first DataFrame in the dictionary
eb0_sensor_df = next(iter(eb0_sensor_df_dict.values()))

# Merge the rest of the DataFrames
for key, df in list(eb0_sensor_df_dict.items())[1:]:
    eb0_sensor_df = eb0_sensor_df.merge(df, on='DateTime', how='outer')

# Sort the final DataFrame by 'DateTime'
eb0_sensor_df.sort_values('DateTime', inplace=True)

# %%
# Sort columns after DateTime by name
eb0_sensor_df = eb0_sensor_df.reindex(sorted(eb0_sensor_df.columns), axis=1)

# move DateTime to the first column
col = eb0_sensor_df.pop('DateTime')
eb0_sensor_df.insert(0, 'DateTime', col)

# %%
eb0_sensor_df
# Out:
#                   DateTime  ALARMA ESPECTRAL     COLOR        COND        OX  \
# 107831 2022-01-01 00:00:00           0.39889  23.50000     0.00000   0.00000
# 107832 2022-01-01 00:05:00           0.40208  23.50000     0.00000   0.00000
# 107833 2022-01-01 00:10:00           0.38262  23.55417     0.00000   0.00000
# 107834 2022-01-01 00:15:00           0.39108  23.50000     0.00000   0.00000
# 107835 2022-01-01 00:20:00           0.38574  23.53750     0.00000   0.00000
# ...                    ...               ...       ...         ...       ...
# 108464 2023-01-12 14:40:00               NaN       NaN  1602.61667  10.31450
# 108465 2023-01-12 14:45:00               NaN       NaN  1602.30000  10.31800
# 108466 2023-01-12 14:50:00               NaN       NaN  1602.96667  10.33750
# 108467 2023-01-12 14:55:00               NaN       NaN  1603.01667  10.31017
# 108468 2023-01-12 15:00:00               NaN       NaN         NaN       NaN
#
#         PARTICULES       PH  RATIO_HG  RATIO_TERB_SIG  RATIO_TLF_UV  \
# 107831      0.0000  0.00000       0.0           34.25           NaN
# 107832      0.0000  0.00000       0.0           34.25           NaN
# 107833      0.0000  0.00000       0.0           34.25           NaN
# 107834      0.0000  0.00000       0.0           34.25           NaN
# 107835      0.0000  0.00000       0.0           34.25           NaN
# ...            ...      ...       ...             ...           ...
# 108464  11306.9037  8.42821       NaN             NaN           NaN
# 108465  11249.4923  8.42804       NaN             NaN           NaN
# 108466  11249.4923  8.42858       NaN             NaN           NaN
# 108467  11250.1750      NaN       NaN             NaN           NaN
# 108468         NaN      NaN       NaN             NaN           NaN
#
#             SULFAT      TEMP  TEMP_AIGUA  TERBOLESA  TLF  UV254  VIS436  \
# 107831     0.00000  15.68594     0.00000     11.625  NaN    NaN  10.125
# 107832     0.00000  15.68594     0.00000     11.625  NaN    NaN  10.125
# 107833     0.00000  15.68594     0.00000     11.625  NaN    NaN  10.125
# 107834     0.00000  15.68594     0.00000     11.625  NaN    NaN  10.125
# 107835     0.00000  15.68594     0.00000     11.625  NaN    NaN  10.125
# ...            ...       ...         ...        ...  ...    ...     ...
# 108464  1602.61667       NaN    12.61750        NaN  NaN    NaN     NaN
# 108465  1602.30000       NaN    12.61975        NaN  NaN    NaN     NaN
# 108466  1602.96667       NaN    12.60700        NaN  NaN    NaN     NaN
# 108467  1603.01667       NaN    12.60175        NaN  NaN    NaN     NaN
# 108468  1603.08333       NaN    12.60100        NaN  NaN    NaN     NaN
#
#          VIS525   VIS620
# 107831  7.50000  5.90625
# 107832  7.48646  5.90625
# 107833  7.51354  5.91979
# 107834  7.50000  5.90625
# 107835  7.50312  5.91563
# ...         ...      ...
# 108464      NaN      NaN
# 108465      NaN      NaN
# 108466      NaN      NaN
# 108467      NaN      NaN
# 108468      NaN      NaN
#
# [108469 rows x 19 columns]

# %% [markdown]
# ### Remove outliers

# %%
for column in eb0_sensor_df.columns[2:]:
    quartile1, quartile3 = eb0_sensor_df[column].quantile([0.25, 0.75])
    iqr = quartile3 - quartile1
    lower_bound = quartile1 - (1.5 * iqr)
    upper_bound = quartile3 + (1.5 * iqr)
    
    eb0_sensor_df[column] = eb0_sensor_df[column].apply(lambda x: x if (x > lower_bound and x < upper_bound) else None)

eb0_sensor_df.dropna(how="all", inplace=True)

# %%
eb0_sensor_df.to_excel(
    os.path.join(clean_data_path, "EB0_Sensor.xlsx")
)

# %% [markdown]
# ## EB1 online sensor readings

# %%
raw_eb1_sensor_df_dict = load_data_from_folder(eb1_sensor_path)

# %%
new_dict = {}
for key in deepcopy(raw_eb1_sensor_df_dict).keys():
    new_key = " ".join(key.split(" ")[:-1]).upper()
    new_dict[new_key] = deepcopy(raw_eb1_sensor_df_dict).pop(key)
raw_eb1_sensor_df_dict = new_dict

# %%
raw_eb1_sensor_df_dict.keys()
# Out:
# dict_keys(['PH', 'DOC', 'CONDUCTIVITAT', 'COLOR', 'TERBOLESA SCAN', 'ORP', 'UVA', 'TERBOLESA', 'ALARMA SPECTRAL', 'TLF', 'UVA SCAN', 'TEMPERATURA', 'TOC', 'CLOR LLIURE', 'PARTICULES'])

# %%
# remove SCAN variables from the dictionary since they are less reliable than the other sensors
raw_eb1_sensor_df_dict.pop('TERBOLESA SCAN')
raw_eb1_sensor_df_dict.pop('UVA SCAN')
# Out:
#                     Fecha  Valor
# 0     2022-01-01 00:00:00   2.41
# 1     2022-01-01 00:10:00   2.41
# 2     2022-01-01 00:20:00   2.41
# 3     2022-01-01 00:30:00   2.41
# 4     2022-01-01 00:40:00   2.41
# ...                   ...    ...
# 52555 2022-12-31 23:10:00   1.78
# 52556 2022-12-31 23:20:00   1.78
# 52557 2022-12-31 23:30:00   1.78
# 52558 2022-12-31 23:40:00   1.78
# 52559 2022-12-31 23:50:00   1.78
#
# [52560 rows x 2 columns]

# %%
raw_eb1_sensor_df_dict["PH"]
# Out:
#             Fecha      HORA PAB01_APH_M01_PV
# 0      04/03/2022  18:40:00           7,5528
# 1      04/03/2022  18:50:00          7,55373
# 2      04/03/2022  19:00:00          7,55437
# 3      04/03/2022  19:10:00          7,55684
# 4      04/03/2022  19:20:00          7,55505
# ...           ...       ...              ...
# 51147  22/02/2023  23:10:00          7,40668
# 51148  22/02/2023  23:20:00          7,40796
# 51149  22/02/2023  23:30:00          7,40885
# 51150  22/02/2023  23:40:00          7,40851
# 51151  22/02/2023  23:50:00          7,41081
#
# [51152 rows x 3 columns]

# %%
eb1_sensor_df_dict = deepcopy(raw_eb1_sensor_df_dict)

# %%
for key, item in eb1_sensor_df_dict.items():
    item.dropna(inplace=True)
    item["Fecha"] = pd.to_datetime(
        item["Fecha"].astype(str).str.lstrip(), format='%d/%m/%Y', errors="coerce"
    ).dt.date

    # if HORA is in the column list
    if "HORA" in item.columns:
        item.drop(item[item["HORA"] == "0"].index, inplace=True)
        item["HORA"] = pd.to_datetime(item["HORA"], format="%H:%M:%S").dt.time

        item.insert(
            loc=0,
            column="DateTime",
            value=pd.to_datetime(
                item["Fecha"].astype(str) + " " + item["HORA"].astype(str)
            ),
        )
        item.drop(columns=["Fecha", "HORA"], inplace=True)
    else:
        item.insert(
            loc=0,
            column="DateTime",
            value=item["Fecha"],
        )
        item.drop(columns=["Fecha"], inplace=True)

    for col in item.columns[1:]:
        item[col] = item[col].replace("n/a", None, regex=True)
        item.dropna(inplace=True)
        item[col] = item[col].replace(",", ".", regex=True)
        item[col] = item[col].astype(float)
        
    eb1_sensor_df_dict[key] = item[(item["DateTime"] >= eb1_min_date) & (item["DateTime"] <= eb1_max_date)]

# %%
# the column that contains the measured value is the first one containing _PV
# rename it with the name of the measured parameter
for key, item in eb1_sensor_df_dict.items():
    for col in item.columns:
        if "_PV" in col:
            item.rename(columns={col: key}, inplace=True)
            break

# %%
# a sample is considered valid if the columns after the one containing the measured value (the second one) are all equal to 0
# if not, the sample is considered invalid and is dropped
for key, item in eb1_sensor_df_dict.items():
    # Select the columns after the second one and check if all values are equal to 0
    mask = (item.iloc[:, 2:] != 0).any(axis=1)
    
    # Drop the rows where the mask is True
    item.drop(item[mask].index, inplace=True)
    
    # Drop the columns after the second one
    item.drop(columns=item.columns[2:], inplace=True)

# %%
# get the median sampling rate for each sensor to retrieve the most frequent sampling rate
sampling_rates = {}
for key, item in eb1_sensor_df_dict.items():
    sampling_rates[key] = item["DateTime"].diff().median()

# get the most frequent sampling rate
sampling_rate = max(set(sampling_rates.values()), key=list(sampling_rates.values()).count)

# resample the dataframes to the most frequent sampling rate
for key, item in eb1_sensor_df_dict.items():
    item.set_index("DateTime", inplace=True)
    item = item[~item.index.duplicated(keep='first')]
    item = item.resample(sampling_rate).interpolate(method="time")
    item.reset_index(inplace=True)
    eb1_sensor_df_dict[key] = item

# %%
# Initialize the final DataFrame with the first DataFrame in the dictionary
eb1_sensor_df = next(iter(eb1_sensor_df_dict.values()))

# Merge the rest of the DataFrames
for key, df in list(eb1_sensor_df_dict.items())[1:]:
    eb1_sensor_df = eb1_sensor_df.merge(df, on='DateTime', how='outer')

# Sort the final DataFrame by 'DateTime'
eb1_sensor_df.sort_values('DateTime', inplace=True)

# %%
# Sort columns after DateTime by name
eb1_sensor_df = eb1_sensor_df.reindex(sorted(eb1_sensor_df.columns), axis=1)

# move DateTime to the first column
col = eb1_sensor_df.pop('DateTime')
eb1_sensor_df.insert(0, 'DateTime', col)

# %%
eb1_sensor_df
# Out:
#                  DateTime  ALARMA SPECTRAL  CLOR LLIURE    COLOR  \
# 56787 2020-03-03 01:10:00              NaN      0.82440  2.12500
# 56788 2020-03-03 01:20:00              NaN      0.87208  2.12500
# 56789 2020-03-03 01:30:00              NaN      0.95753  2.12500
# 56790 2020-03-03 01:40:00              NaN      0.94611  2.12500
# 56791 2020-03-03 01:50:00              NaN      0.95713  2.12500
# ...                   ...              ...          ...      ...
# 47742 2023-01-30 07:40:00          4.87760      0.98852  0.62109
# 47743 2023-01-30 07:50:00          4.87500      0.98701  0.62109
# 47744 2023-01-30 08:00:00          4.90625      0.98575  0.62109
# 47745 2023-01-30 08:10:00          4.85000      0.98453  0.62109
# 47746 2023-01-30 08:20:00          4.93021      0.98046  0.62109
#
#        CONDUCTIVITAT  DOC    ORP  PARTICULES       PH  TEMPERATURA  TERBOLESA  \
# 56787          840.0  NaN    NaN         NaN      NaN     13.81094        NaN
# 56788          840.0  NaN    NaN         NaN      NaN     13.81094        NaN
# 56789          840.0  NaN    NaN         NaN      NaN     13.81094        NaN
# 56790          840.0  NaN    NaN         NaN      NaN     13.81094        NaN
# 56791          840.0  NaN    NaN         NaN      NaN     13.81094        NaN
# ...              ...  ...    ...         ...      ...          ...        ...
# 47742         1520.0  NaN  608.0   630.77438  7.63589     11.37344    0.03050
# 47743         1520.0  NaN  608.0   602.10281  7.63695     11.37344    0.03050
# 47744         1520.0  NaN  608.0   607.73473  7.63576     11.37344    0.03250
# 47745         1520.0  NaN  608.0   605.68676  7.63567     11.37344    0.02779
# 47746         1520.0  NaN  608.0   602.10281  7.63512     11.37344    0.03017
#
#            TLF  TOC   UVA
# 56787      NaN  NaN  1.67
# 56788      NaN  NaN  1.67
# 56789      NaN  NaN  1.67
# 56790      NaN  NaN  1.68
# 56791      NaN  NaN  1.68
# ...        ...  ...   ...
# 47742  4.05000  NaN  1.78
# 47743  4.06250  NaN  1.78
# 47744  4.06250  NaN  1.78
# 47745  4.06771  NaN  1.78
# 47746  4.06250  NaN  1.78
#
# [153116 rows x 14 columns]

# %% [markdown]
# ### Removing outliers

# %%
for column in eb1_sensor_df.columns[2:]:
    quartile1, quartile3 = eb1_sensor_df[column].quantile([0.25, 0.75])
    iqr = quartile3 - quartile1
    lower_bound = quartile1 - (1.5 * iqr)
    upper_bound = quartile3 + (1.5 * iqr)
    
    eb1_sensor_df[column] = eb1_sensor_df[column].apply(lambda x: x if (x > lower_bound and x < upper_bound) else None)

eb1_sensor_df.dropna(how="all", inplace=True)

# %%
eb1_sensor_df.to_excel(
    os.path.join(clean_data_path, "EB1_Sensor.xlsx")
)

# %% [markdown]
# # THM measurements

# %%
# remove the last ";" from the last line of the file

with open(thm_measure_path, "r") as file:
    lines = file.readlines()

    corrected_lines = []
    line_iter = iter(lines)
    max_len = 0
    for line in line_iter:
        line = line.rstrip(";\n") + "\n"
        corrected_lines.append(line)

with open(thm_measure_path, "w") as file:
    file.writelines(corrected_lines)

# %%
raw_thm_measure_df = pd.read_csv(thm_measure_path, sep=";", na_filter=False)

# %%
raw_thm_measure_df
# Out:
#           Data     PM  Hora   TCM   DCBM   CDBM    TBM  TTHMs
# 0   21/07/2021  Arboç  9h00  5.50  13.30  21.20   9.40  49.40
# 1   05/10/2021  Arboç  9h15  5.60  16.20  27.80  16.20  65.80
# 2   19/10/2021  Arboç  9h05  4.10  13.00  27.20  16.10  60.40
# 3   09/11/2021  Arboç  8h52  1.25   9.20  21.80  15.80  46.80
# 4   01/12/2021  Arboç  8h40  0.00   8.30  22.50  17.50  48.30
# 5   01/02/2022  Arboç  9h00  2.97   6.07  10.53   3.99  23.56
# 6   15/02/2022  Arboç  8h40  5.17   8.50  12.26   2.49  28.41
# 7   01/03/2022  Arboç  8h30  3.69   7.36  12.24   3.41  26.71
# 8   15/03/2022  Arboç  8h30  3.39   7.37  12.75   4.08  27.59
# 9   29/03/2022  Arboç  8h45  3.73   8.33  15.93   6.13  34.12
# 10  05/04/2022  Arboç  8h40  4.20   8.60  14.50   5.50  32.80
# 11  20/04/2022  Arboç  8h55  5.30  11.00  16.00   5.50  37.80
# 12  04/05/2022  Arboç  9h00  5.20  11.00  18.00   5.40  40.00
# 13  18/05/2022  Arboç  8h50  4.30   9.10  14.80   6.10  34.30
# 14  31/05/2022  Arboç  8h25  3.20   6.40   9.80   3.70  23.10
# 15  14/06/2022  Arboç  8h15  6.00  12.50  19.10   6.60  44.20
# 16  29/06/2022  Arboç  8h30  6.80  14.30  21.00   6.70  48.80
# 17  13/07/2022  Arboç  8h35  6.90  12.70   0.00   6.20  25.80
# 18  27/07/2022  Arboç  8h00  1.25  15.60  21.50   7.20  44.30
# 19  10/08/2022  Arboç  8h05  6.10  12.40  18.80   7.30  44.60
# 20  18/08/2022  Arboç  8h15  8.70  16.90  26.90  11.50  64.00
# 21  07/09/2022  Arboç  8h35  6.00  14.10  24.60  11.70  56.40
# 22  21/09/2022  Arboç  8h30  6.40  17.10  30.40  13.80  67.70
# 23  05/10/2022  Arboç  8h05  3.50  12.00  25.30  13.60  54.40
# 24  19/10/2022  Arboç  8h15  4.20  13.20  27.00  15.70  55.90
# 25  08/11/2022  Arboç  8h25  4.20  12.30  24.10  13.00  53.60
# 26  16/11/2022  Arboç  8h20  4.10  11.50  26.70  17.00  59.30
# 27  14/12/2022  Arboç  8h15  3.10   9.10  20.20  13.50  45.90
# 28  21/12/2022  Arboç  8h25  3.00   8.50  19.20  12.80  43.50
# 29  11/01/2023  Arboç  8h40  2.30   7.30  18.30  11.50  39.40
# 30  25/01/2023  Arboç  8h50  2.00   6.70  18.20  14.10  41.00

# %%
thm_measure_df = deepcopy(raw_thm_measure_df)

# %%
thm_measure_df["Data"] = pd.to_datetime(
    thm_measure_df["Data"], format="%d/%m/%Y"
).dt.date


thm_measure_df["Hora"] = pd.to_datetime(
    thm_measure_df["Hora"], format="%Hh%M"
).dt.time

# %%
thm_measure_df[["TCM", "DCBM", "CDBM", "TBM", "TTHMs"]] = thm_measure_df[
    ["TCM", "DCBM", "CDBM", "TBM", "TTHMs"]
].astype(float)

# %%
thm_measure_df.drop(columns=["PM"], inplace=True)

# %%
# union of the date and time columns
thm_measure_df.insert(
    loc=0,
    column="DateTime",
    value=pd.to_datetime(
        thm_measure_df["Data"].astype(str)
        + " "
        + thm_measure_df["Hora"].astype(str)
    ),
)

# %%
thm_measure_df.drop(columns=["Data", "Hora"], inplace=True)

# %%
thm_measure_df
# Out:
#               DateTime   TCM   DCBM   CDBM    TBM  TTHMs
# 0  2021-07-21 09:00:00  5.50  13.30  21.20   9.40  49.40
# 1  2021-10-05 09:15:00  5.60  16.20  27.80  16.20  65.80
# 2  2021-10-19 09:05:00  4.10  13.00  27.20  16.10  60.40
# 3  2021-11-09 08:52:00  1.25   9.20  21.80  15.80  46.80
# 4  2021-12-01 08:40:00  0.00   8.30  22.50  17.50  48.30
# 5  2022-02-01 09:00:00  2.97   6.07  10.53   3.99  23.56
# 6  2022-02-15 08:40:00  5.17   8.50  12.26   2.49  28.41
# 7  2022-03-01 08:30:00  3.69   7.36  12.24   3.41  26.71
# 8  2022-03-15 08:30:00  3.39   7.37  12.75   4.08  27.59
# 9  2022-03-29 08:45:00  3.73   8.33  15.93   6.13  34.12
# 10 2022-04-05 08:40:00  4.20   8.60  14.50   5.50  32.80
# 11 2022-04-20 08:55:00  5.30  11.00  16.00   5.50  37.80
# 12 2022-05-04 09:00:00  5.20  11.00  18.00   5.40  40.00
# 13 2022-05-18 08:50:00  4.30   9.10  14.80   6.10  34.30
# 14 2022-05-31 08:25:00  3.20   6.40   9.80   3.70  23.10
# 15 2022-06-14 08:15:00  6.00  12.50  19.10   6.60  44.20
# 16 2022-06-29 08:30:00  6.80  14.30  21.00   6.70  48.80
# 17 2022-07-13 08:35:00  6.90  12.70   0.00   6.20  25.80
# 18 2022-07-27 08:00:00  1.25  15.60  21.50   7.20  44.30
# 19 2022-08-10 08:05:00  6.10  12.40  18.80   7.30  44.60
# 20 2022-08-18 08:15:00  8.70  16.90  26.90  11.50  64.00
# 21 2022-09-07 08:35:00  6.00  14.10  24.60  11.70  56.40
# 22 2022-09-21 08:30:00  6.40  17.10  30.40  13.80  67.70
# 23 2022-10-05 08:05:00  3.50  12.00  25.30  13.60  54.40
# 24 2022-10-19 08:15:00  4.20  13.20  27.00  15.70  55.90
# 25 2022-11-08 08:25:00  4.20  12.30  24.10  13.00  53.60
# 26 2022-11-16 08:20:00  4.10  11.50  26.70  17.00  59.30
# 27 2022-12-14 08:15:00  3.10   9.10  20.20  13.50  45.90
# 28 2022-12-21 08:25:00  3.00   8.50  19.20  12.80  43.50
# 29 2023-01-11 08:40:00  2.30   7.30  18.30  11.50  39.40
# 30 2023-01-25 08:50:00  2.00   6.70  18.20  14.10  41.00

# %%
thm_measure_df.to_excel(
    os.path.join(clean_data_path, "THMs.xlsx")
)
